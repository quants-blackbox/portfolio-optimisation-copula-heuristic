# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Importing libraries
from RiskLabAI import *
from src.optimisation.hmv.clustering import dependence_matrix, clustering_matrix

import warnings

warnings.filterwarnings('ignore')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Importing libraries
# ----> 2 from RiskLabAI import *
#       3 from src.optimisation.hmv.clustering import dependence_matrix, clustering_matrix
#       4
#       5 import warnings
#
# File ~/miniconda3/envs/masters-env/lib/python3.11/site-packages/RiskLabAI/pde/__init__.py:8
#       1 """
#       2 RiskLabAI PDE Solver Module
#       3
#       4 Implements a Deep BSDE (Backward Stochastic Differential Equation)
#       5 solver for various financial PDEs.
#       6 """
# ----> 8 from .equation import (
#       9     Equation,
#      10     PricingDefaultRisk,
#      11     HJBLQ,
#      12     BlackScholesBarenblatt,
#      13     PricingDiffRate,
#      14 )
#      15 from .model import (
#      16     TimeNet,
#      17     Net1,
#    (...)     27     TimeDependentNetworkMonteCarlo,
#      28 )
# ...

# %%
cluster_matrix = clustering_matrix()

# %%
cluster_matrix
